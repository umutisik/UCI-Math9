# %% [markdown]
# ## Homework 1
#
# Please fill this notebook with your code, run everthing, save the notebook and upload to canvas.

# %%
# libhw01 includes the drawing and graphing functions we are going to use
import libhw01 as hwlib
# can't do math without math can we?
import math

# %%
hwlib.graphfunction(f)

# %% [markdown]
# Run this

# %%
def f(x):
    return math.sin(math.pi*x)

# %%
hwlib.graphfunction(f)

# %% [markdown]
# ### Problem 1
#
# Please write the functions that would produce the graphs in the homework description.

# %% [markdown]
# ### Problem 2

# %%
def fun1(x,y):
    return x**2 + y**2
hwlib.drawfunction(fun1)

# %% [markdown]
# ### Problem 3
#
# Make a function you think gives an interesting result when we take `hwlib.drawfunc(f)`
# We will use the most interesting functions to challenge your colleagues.

# %% [markdown]
# ### Problem 4
#
# Functions of functions.
# Functions are just like any other variable and can be returned from functions
# Write down a function called `rotateleft` that will take a function f and will rotate its picture.

# %%
def rotateleft(f):
    def g(x,y):
        return f(y, -x)
    return g

# %%
def fun(x,y):
    return abs(x+y)
hwlib.drawfunction(fun)

# %%
hwlib.drawfunction(rotateleft(fun))

# %% [markdown]
# Now make a function that repeats the picture like in the problem description

# %%
def repeat(f):
    def g(x,y):
        ...
    return g

# %%
hwlib.drawfunction(repeat(fun))
